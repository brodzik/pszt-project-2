# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("seaborn")

# %%
df = pd.read_csv("data/bank-additional-full.csv", sep=";")

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %%
list(df.columns)
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'y']

# %%
df["job"].value_counts().plot(kind="bar")
plt.title("type of job")
# Out:
# Text(0.5, 1.0, 'type of job')

# %%
df["marital"].value_counts().plot(kind="bar")
plt.title("marital status")
# Out:
# Text(0.5, 1.0, 'marital status')

# %%
df["education"].value_counts().plot(kind="bar")
plt.title("education degree")
# Out:
# Text(0.5, 1.0, 'education degree')

# %%
df["default"].value_counts().plot(kind="bar")
plt.title("has credit in default")
# Out:
# Text(0.5, 1.0, 'has credit in default')

# %%
df["housing"].value_counts().plot(kind="bar")
plt.title("has housing loan")
# Out:
# Text(0.5, 1.0, 'has housing loan')

# %%
df["loan"].value_counts().plot(kind="bar")
plt.title("has personal loan")
# Out:
# Text(0.5, 1.0, 'has personal loan')

# %%
df["contact"].value_counts().plot(kind="bar")
plt.title("contact communication type")
# Out:
# Text(0.5, 1.0, 'contact communication type')

# %%
df["month"].value_counts().plot(kind="bar")
plt.title("last contact month of year")
# Out:
# Text(0.5, 1.0, 'last contact month of year')

# %%
df["day_of_week"].value_counts().plot(kind="bar")
plt.title("last contact day of the week")
# Out:
# Text(0.5, 1.0, 'last contact day of the week')

# %%
df["poutcome"].value_counts().plot(kind="bar")
plt.title("outcome of the previous marketing campaign")
# Out:
# Text(0.5, 1.0, 'outcome of the previous marketing campaign')

# %%
plt.hist(df["age"], bins=range(10, 90, 5))
plt.title("age")
# Out:
# Text(0.5, 1.0, 'age')

# %%
plt.hist(df["duration"], bins=range(0, 3000, 100))
plt.title("last contact duration, in seconds")
# Important note:  this attribute highly affects the output target (e.g., if duration=0 then y="no").
# Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known.
# Thus, this input should only be included for benchmark purposes and should be discarded
# if the intention is to have a realistic predictive model.
# Out:
# Text(0.5, 1.0, 'last contact duration, in seconds')

# %%
plt.hist(df["campaign"], bins=range(1, 30, 1))
plt.title("number of contacts performed during this campaign and for this client")
# Out:
# Text(0.5, 1.0, 'number of contacts performed during this campaign and for this client')

# %%
plt.hist(df["pdays"])
plt.title("number of days that passed by after the client was last contacted from a previous campaign")
# Out:
# Text(0.5, 1.0, 'number of days that passed by after the client was last contacted from a previous campaign')

# %%
plt.hist(df["previous"])
plt.title("number of contacts performed before this campaign and for this client")
# Out:
# Text(0.5, 1.0, 'number of contacts performed before this campaign and for this client')

# %%
plt.hist(df["emp.var.rate"])
plt.title("employment variation rate - quarterly indicator")
# Out:
# Text(0.5, 1.0, 'employment variation rate - quarterly indicator')

# %%
plt.hist(df["cons.price.idx"])
plt.title("consumer price index - monthly indicator")
# Out:
# Text(0.5, 1.0, 'consumer price index - monthly indicator')

# %%
plt.hist(df["cons.conf.idx"])
plt.title("consumer confidence index - monthly indicator")
# Out:
# Text(0.5, 1.0, 'consumer confidence index - monthly indicator')

# %%
plt.hist(df["euribor3m"])
plt.title("euribor 3 month rate - daily indicator")
# Out:
# Text(0.5, 1.0, 'euribor 3 month rate - daily indicator')

# %%
plt.hist(df["nr.employed"])
plt.title("number of employees - quarterly indicator")
# Out:
# Text(0.5, 1.0, 'number of employees - quarterly indicator')
